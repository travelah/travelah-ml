# %% [markdown]
# ##**Proyek Akhir Bangkit 2023 : *Travelah Mobile Application Recommender System***

# %% [markdown]
# ## **Updating Bali Travelspot Datasets**
#
# Adding rating_google, location like lang & lng, and the formmated addres

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Code buat Misahin Kecamatan, Kabupaten**

# %%
# import pandas as pd
# import requests
# import time


# import pandas as pd
# import re

# # Step 1: Read the Excel file into a DataFrame
# df = pd.read_excel('/content/drive/MyDrive/Bangkit 2023/Dataset/Final/food_datasets_final_updated.xlsx')


# # Function to extract Kecamatan and Kabupaten from formatted_address
# def extract_region(address):
#     kecamatan = re.search(r'Kec(?:amatan)?[.,\s]+([\w\s]+)', address)
#     kabupaten = re.search(r'(?:Regency|Kab(?:upaten)?|Kab\.?)[.,\s]+([\w\s]+)', address)
    
#     if kecamatan and kabupaten:
#         return f"{kecamatan.group(1).strip()}, {kabupaten.group(1).strip()}"
#     else:
#         return None

# # Apply the function to create the region column
# df['formatted_region'] = df['location'].apply(extract_region)


# # Step 5: Save the updated DataFrame to Excel
# df.to_excel('/content/drive/MyDrive/Bangkit 2023/Dataset/Final/food_datasets_final_updated_with_region.xlsx', index=False)

# %%
# import pandas as pd
# import requests
# import time
# from google.colab import drive
# drive.mount('/content/drive')

# def get_place_details(place, api_key, radius=50):
#     """
#     Get the details of a place using its name and API key.

#     Returns a dictionary containing the place's name, formatted address, and location.
#     """
#     url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
#     params = {
#         "query": place,
#         "key": api_key,
#         "radius": radius
#     }
#     response = requests.get(url, params=params)
#     data = response.json()
#     if response.status_code != 200:
#         print(f"Error retrieving details for {place}. Status code: {response.status_code}")
#         return {}
#     if data.get("status") != "OK":
#         print(f"Unable to retrieve details for {place}. API response: {data.get('status')} - {data.get('error_message')}")
#         return {}
#     result = {}
#     if data.get("results"):
#         place_data = data["results"][0]
#         result["name"] = place_data.get("name")
#         result["formatted_address"] = place_data.get("formatted_address")
#         result["location"] = place_data.get("geometry", {}).get("location")
#         result["rating"] = place_data.get("rating")
#     return result


# # Step 1: Read the Excel file into a DataFrame
# df = pd.read_excel('/content/drive/MyDrive/Bangkit 2023/Dataset/Final/tripadvisor_food_datasets.xlsx')

# # Step 2: Define your API key
# api_key_gmaps = 'AIzaSyA9qOj7YVTO4RvArqJ5OOZ9P7oEXSEZ4II'

# # Step 3: Add new columns to the DataFrame
# df['location'] = ''
# df['formatted_address'] = ''
# df['rating_google'] = ''

# # Step 4: Iterate over the DataFrame and update locations and formatted addresses
# for index, row in df.iterrows():
#     place = row['place_name']
#     place_details = get_place_details(place, api_key_gmaps)
#     if place_details:
#         df.at[index, 'location'] = place_details.get('location')
#         df.at[index, 'formatted_address'] = place_details.get('formatted_address')
#         df.at[index, 'rating_google'] = place_details.get('rating')
#     else:
#         print(f"Unable to retrieve details for {place}. Skipping...")

#     # Add a delay of 1 second between API requests to avoid rate limiting
#     time.sleep(1)

# # Step 5: Save the updated DataFrame to Excel
# df.to_excel('/content/drive/MyDrive/Bangkit 2023/Dataset/Final/food_datasets_final_updated.xlsx', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Unable to retrieve details for Secret Cafe. API response: ZERO_RESULTS - None
# Unable to retrieve details for Secret Cafe. Skipping...
# Unable to retrieve details for Warung Suka Sari. API response: ZERO_RESULTS - None
# Unable to retrieve details for Warung Suka Sari. Skipping...
# Unable to retrieve details for Waroeng Jadul Blangkon. API response: ZERO_RESULTS - None
# Unable to retrieve details for Waroeng Jadul Blangkon. Skipping...
# Unable to retrieve details for Warung Sari. API response: ZERO_RESULTS - None
# Unable to retrieve details for Warung Sari. Skipping...
# Unable to retrieve details for Ayam Yummy. API response: ZERO_RESULTS - None
# Unable to retrieve details for Ayam Yummy. Skipping...
# Unable to retrieve details for Warung Makan De 5. API response: ZERO_RESULTS - None
# ...

# %%
# import pandas as pd
# import requests
# import re
# # Step 1: Read the Excel file into a DataFrame
# df = pd.read_excel('/content/drive/MyDrive/Bangkit 2023/Dataset/Final/booking_datasets_final.xlsx')


# # Step 2: Define your API key
# api_key_gmaps= 'AIzaSyA9qOj7YVTO4RvArqJ5OOZ9P7oEXSEZ4II' 
# # endpoint = 'https://en.wikipedia.org/w/api.php'


# # Step 3: Add new columns for rating, location, and formatted address
# df['rating_google'] = ""
# df['location'] = ""
# df['formatted_address'] = ""
# # df['description'] = ""

# %%
# import pandas as pd
# import requests
# import time

# def get_place_details(place, api_key):
#     """
#     Get the details of a place using its name and API key.

#     Returns a dictionary containing the place's name, formatted address, and location.
#     """
#     url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
#     params = {
#         "input": place,
#         "inputtype": "textquery",
#         "fields": "name,rating,formatted_address,geometry/location",
#         "key": api_key
#     }
#     response = requests.get(url, params=params)
#     data = response.json()
#     if response.status_code != 200:
#         print(f"Error retrieving details for {place}. Status code: {response.status_code}")
#         return {}
#     if data.get("status") != "OK":
#         print(f"Unable to retrieve details for {place}. API response: {data.get('status')}")
#         return {}
#     result = {}
#     if data.get("candidates"):
#         place_data = data["candidates"][0]
#         result["name"] = place_data.get("name")
#         result["formatted_address"] = place_data.get("formatted_address")
#         result["rating"] = place_data.get("rating")
#         result["location"] = place_data.get("geometry", {}).get("location")
#     return result

# # Step 1: Read the Excel file into a DataFrame
# df = pd.read_excel('/content/drive/MyDrive/Bangkit 2023/Dataset/booking_datasets_final.xlsx')

# # Step 2: Define your API key
# api_key_gmaps = 'AIzaSyA9qOj7YVTO4RvArqJ5OOZ9P7oEXSEZ4II'

# # Step 3: Add new columns to the DataFrame
# df['rating_google'] = ''
# df['location'] = ''
# df['formatted_address'] = ''

# # Step 4: Iterate over the DataFrame and update ratings, locations, and formatted addresses
# for index, row in df.iterrows():
#     place = row['name_hotel']
#     place_details = get_place_details(place, api_key_gmaps)
#     if place_details:
#         df.at[index, 'rating_google'] = place_details.get('rating')
#         df.at[index, 'location'] = place_details.get('location')
#         df.at[index, 'formatted_address'] = place_details.get('formatted_address')
#     else:
#         print(f"Unable to retrieve details for {place}. Skipping...")

#     # Add a delay of 1 second between API requests to avoid rate limiting
#     time.sleep(1)

# # Step 5: Save the updated DataFrame to Excel
# df.to_excel('/content/drive/MyDrive/Bangkit 2023/Dataset/booking_datasets_final_updated.xlsx', index=False)
# Out:
# Unable to retrieve details for MaxOne Rejuvination @Gianyar. API response: REQUEST_DENIED - This API project is not authorized to use this API.
# Unable to retrieve details for MaxOne Rejuvination @Gianyar. Skipping...
# Unable to retrieve details for Swan Paradise A Pramana Experience - CHSE Certified. API response: REQUEST_DENIED - This API project is not authorized to use this API.
# Unable to retrieve details for Swan Paradise A Pramana Experience - CHSE Certified. Skipping...
# Unable to retrieve details for North Wing Canggu Resort. API response: REQUEST_DENIED - This API project is not authorized to use this API.
# Unable to retrieve details for North Wing Canggu Resort. Skipping...
# Unable to retrieve details for Louka Beach Bali. API response: REQUEST_DENIED - This API project is not authorized to use this API.
# Unable to retrieve details for Louka Beach Bali. Skipping...
# ...

# %%
# def get_place_details(place, api_key_gmaps):
#     """
#     Get the details of a place using its name and API key.

#     Returns a dictionary containing the place's name, formatted address, and rating.
#     """
#     url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={place}&inputtype=textquery&fields=name,rating,formatted_address,geometry/location&key={api_key}"
#     response = requests.get(url)
#     data = response.json()
#     result = {}
#     if data.get("candidates"):
#         place_data = data["candidates"][0]
#         result["name"] = place_data.get("name")
#         result["formatted_address"] = place_data.get("formatted_address")
#         result["rating"] = place_data.get("rating")
#         result["location"] = place_data.get("geometry", {}).get("location")
#     return result

# # def get_place_description(place, endpoint):
# #     """
# #     Get the description of a place using its name and the MediaWiki API.

# #     Returns a string containing the description.
# #     """
# #     # Format the query parameters
# #     params = {
# #         'action': 'query',
# #         'format': 'json',
# #         'prop': 'extracts',
# #         'exintro': '',
# #         'explaintext': '',
# #         'titles': place
# #     }

# #     # Make the API request
# #     response = requests.get(endpoint, params=params)
# #     data = response.json()
    
# #     # Extract the description from the API response
# #     pages = data.get('query', {}).get('pages')
# #     if pages:
# #         page_id = next(iter(pages))
# #         description = pages[page_id].get('extract', '')
# #         return description

# #     return ""


# def extract_city_from_compound_code(compound_code):
#     if isinstance(compound_code, str):
#         match = re.search(r'(\w+),', compound_code)
#         if match:
#             return match.group(1)
#     return ''

# # Step 4: Iterate over the DataFrame and update ratings, locations, and formatted addresses
# for index, row in df.iterrows():
#     place = row['name_hotel']
#     place_details = get_place_details(place, api_key_gmaps)
#     # description = get_place_description(place, endpoint)
#     df.at[index, 'rating_google'] = place_details.get('rating')
#     df.at[index, 'location'] = place_details.get('location')
#     df.at[index, 'formatted_address'] = place_details.get('formatted_address')
#     # city = extract_city_from_compound_code(place_details.get('city'))
#     # df.at[index, 'city'] = city
#     # df.at[index, 'description'] = description

# # Step 5: Save the updated DataFrame to Excel
# df.to_excel('/content/drive/MyDrive/Bangkit 2023/Dataset/booking_datasets_v2.xlsx', index=False)

# # df = df[df['formatted_address'].str.contains('Bali', na=False, case=False) & df['formatted_address'].notna()]

# # # Step 5: Save the updated DataFrame to Excel
# # df.to_csv('/content/drive/MyDrive/Bangkit 2023/Dataset/updated_bali_zoo_sight_dataset_v3.csv', index=False)

# %% [markdown]
# ## **Data Description**
#
# Sumber: Scrapped TripAdvisor Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow==2.12.0

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
import re
from nltk.corpus import stopwords as nltk_stopwords
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy
import random
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %%
travel_df = pd.read_csv("/content/drive/MyDrive/Bangkit 2023/Dataset/Final/travel_spot_datasets_final_v2.csv")
hotel_df = pd.read_csv('/content/drive/MyDrive/Bangkit 2023/Dataset/Final/booking_datasets_final_updated_with_region.csv')
food_df = pd.read_csv('/content/drive/MyDrive/Bangkit 2023/Dataset/Final/food_datasets_final_updated_with_region.csv')
travel_df.head()
# Out:
#    index                                             source  \
# 0      1  https://www.tripadvisor.com/Attraction_Review-...
# 1      2  https://www.tripadvisor.com/Attraction_Review-...
# 2      3  https://www.tripadvisor.com/Attraction_Review-...
# 3      4  https://www.tripadvisor.com/Attraction_Review-...
# 4      5  https://www.tripadvisor.com/Attraction_Review-...
#
#                      place rating_label  rating_google review_label  \
# 0  Tegalalang Rice Terrace         High            4.4  Exceptional
# 1         Tanah Lot Temple         High            4.8  Exceptional
# 2           Uluwatu Temple         High            4.6  Exceptional
# 3      Campuhan Ridge Walk         High            4.4    Wonderful
# 4       Tirta Empul Temple         High            4.6  Exceptional
#
#   review_count            type_category  \
# 0        16781     Nature POI Landmarks
# 1        11140  Religious POI Landmarks
# 2        10154                Religious
# ...

# %%
hotel_df.head()
# Out:
#                                          source_href  \
# 0  https://www.booking.com/hotel/id/maxone-rejuvi...
# 1  https://www.booking.com/hotel/id/swan-paradise...
# 2  https://www.booking.com/hotel/id/north-wing-ca...
# 3  https://www.booking.com/hotel/id/louka-beach-b...
# 4  https://www.booking.com/hotel/id/the-royal-pur...
#
#                                           name_hotel    region  \
# 0                       MaxOne Rejuvination @Gianyar    Balian
# 1  Swan Paradise A Pramana Experience - CHSE Cert...   Gianyar
# 2                           North Wing Canggu Resort    Dalung
# 3                                   Louka Beach Bali   Tianyar
# 4                    The Royal Purnama - Adults Only  Sukawati
#
#                                          description price_label  rating  \
# 0  MaxOne Rejuvination @Gianyar has an outdoor sw...   Expensive     8.7
# 1  Swan Paradise A Pramana Experience - CHSE Cert...   Expensive     8.8
# ...

# %%
food_df.head()
# Out:
#              place_name    region  \
# 0               Wok Wok  Denpasar
# 1    Waroeng Bernadette  Seminyak
# 2     Tablespoon Bistro      Ubud
# 3      Blou Cafe Canggu    Canggu
# 4  Pistachio Restaurant      Ubud
#
#                                               source  review_count   rating  \
# 0  https://www.tripadvisor.com/Restaurant_Review-...           345      Low
# 1  https://www.tripadvisor.com/Restaurant_Review-...          1900     High
# 2  https://www.tripadvisor.com/Restaurant_Review-...           929  Average
# 3  https://www.tripadvisor.com/Restaurant_Review-...           173      Low
# 4  https://www.tripadvisor.com/Restaurant_Review-...           978  Average
#
#                      cuisine eating_type  price    range  \
# 0        Chinese, Indonesian  Cheap Eats  Cheap  21.0 mi
# 1                 Indonesian  Cheap Eats  Cheap  19.5 mi
# 2            Indonesia, Cafe  Cheap Eats  Cheap   7.8 mi
# 3            American, Asian  Cheap Eats  Cheap  17.1 mi
# ...

# %%
unique_values = travel_df['review_label'].unique()
for value in unique_values:
    print(value)
# Out:
# Exceptional
# Wonderful
# Good

# %%
unique_values = hotel_df['price_label'].unique()
for value in unique_values:
    print(value)
# Out:
# Expensive
# Moderate
# Cheap

# %%
# Mencetak dimensi data
print("data: ", travel_df.shape)
# Out:
# data:  (696, 12)

# %%
# Mencetak dimensi data
print("data: ", hotel_df.shape)
# Out:
# data:  (955, 11)

# %%
# Mencetak dimensi data
print("data: ", food_df.shape)
# Out:
# data:  (2492, 15)

# %%
travel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              696 non-null    int64
#  1   source             696 non-null    object
#  2   place              696 non-null    object
#  3   rating_label       696 non-null    object
#  4   rating_google      696 non-null    float64
#  5   review_label       696 non-null    object
#  6   review_count       696 non-null    object
#  7   type_category      696 non-null    object
#  8   keywords           489 non-null    object
#  9   location           696 non-null    object
#  10  formatted_address  696 non-null    object
#  11  region             696 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 65.4+ KB

# %%
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 955 entries, 0 to 954
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   source_href        955 non-null    object
#  1   name_hotel         955 non-null    object
#  2   region             955 non-null    object
#  3   description        955 non-null    object
#  4   price_label        955 non-null    object
#  5   rating             955 non-null    float64
#  6   rating_type        955 non-null    object
#  7   review_count       955 non-null    object
#  8   location           955 non-null    object
#  9   formatted_address  955 non-null    object
#  10  formatted_region   955 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 82.2+ KB

# %%
food_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2492 entries, 0 to 2491
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   place_name        2492 non-null   object
#  1   region            2492 non-null   object
#  2   source            2492 non-null   object
#  3   review_count      2492 non-null   int64
#  4   rating            2492 non-null   object
#  5   cuisine           2492 non-null   object
#  6   eating_type       2492 non-null   object
#  7   price             2492 non-null   object
#  8   range             2492 non-null   object
#  9   comment           2492 non-null   object
#  10  second_comment    2467 non-null   object
#  11  location.1        2492 non-null   object
#  12  rating_google     2372 non-null   float64
#  13  location          2492 non-null   object
#  14  formatted_region  2492 non-null   object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 292.2+ KB

# %%
import re
from nltk.corpus import stopwords as nltk_stopwords

clean_spcl = re.compile('[/(){}\[\]\|@,;]')
clean_symbol = re.compile('[^0-9a-z #+_]')
stop_words = set(nltk_stopwords.words('english'))


def clean_df(text):
    text = text.lower()
    text = re.sub("[^a-zA-Z0-9 ]", "", str(text))
    text = clean_spcl.sub(' ', text)
    text = clean_symbol.sub('', text)
    text = ' '.join(word for word in text.split() if word not in stop_words)
    return text


#Drop Irrelevant Information
# travel_df = travel_df.drop(["source"],axis=1)
# travel_df = travel_df.drop_duplicates(subset='place')
# food_df = food_df.drop(["source"],axis=1)
# food_df = food_df.drop(["range"],axis=1)
# food_df = food_df.drop_duplicates(subset='place_name')
# hotel_df = hotel_df.drop(["source_href"],axis=1)
# hotel_df = hotel_df.drop_duplicates(subset='name_hotel')


#selecting the relevant features for recommendation
selected_features_travel = ['rating_label', 'review_label','type_category','keywords','formatted_address','region']
selected_features_food = ['place_name', 'rating', 'cuisine','eating_type','price','region','formatted_region','comment','second_comment' ]
selected_features_hotel = ['formatted_region', 'price_label','rating_type','description', 'formatted_address', 'region']

#Replace the null values in the selected features with null string
for feature in selected_features_travel:
  travel_df[feature]= travel_df[feature].fillna('')
  travel_df[feature] = travel_df[feature].apply(clean_df)

for feature in selected_features_food:
  food_df[feature]= food_df[feature].fillna('')
  food_df[feature] = food_df[feature].apply(clean_df)

for feature in selected_features_hotel:
  hotel_df[feature]= hotel_df[feature].fillna('')
  hotel_df[feature] = hotel_df[feature].apply(clean_df)


# Reset the index of the DataFrame
travel_df = travel_df.reset_index(drop=True)
hotel_df = hotel_df.reset_index(drop=True)
food_df = food_df.reset_index(drop=True)



travel_df['combined_text'] = travel_df['region'] + ' ' + travel_df['type_category'] + ' ' + travel_df['keywords'] + ' ' + travel_df['formatted_address'] 
food_df['food_clean'] = food_df['formatted_region'] + ' ' + food_df['cuisine'] + ' ' + food_df['rating'] + ' '  + food_df['eating_type'] + ' '+ food_df['price'] + ' '+food_df['region'] + ' '+ food_df['comment'] + ' ' + food_df['second_comment'] 
hotel_df['desc_clean'] = hotel_df['formatted_region'] + ' ' +  hotel_df['price_label'] + ' '+ hotel_df['rating_type'] + ' '  + hotel_df['description'] + ' ' + hotel_df['formatted_address'] + ' '+ hotel_df['region'] 


# Check for missing values in 'combined_text' column
missing_indices_travel = travel_df['combined_text'].isnull()
if missing_indices_travel.any():
    travel_df.loc[missing_indices_travel, 'combined_text'] = ''

# Check for missing values in 'combined_text' column
missing_indices_food = food_df['food_clean'].isnull()
if missing_indices_food.any():
    food_df.loc[missing_indices_food, 'food_clean'] = ''

# Check for missing values in 'combined_text' column
missing_indices_hotel = hotel_df['desc_clean'].isnull()
if missing_indices_hotel.any():
    food_df.loc[missing_indices_hotel, 'food_clean'] = ''

# %%
print(food_df['food_clean'])
# Out:
# 0       denpasar selatan denpasar chinese indonesian l...
# 1       kuta utara badung indonesian high cheap eats c...
# 2       ubud gianyar indonesia cafe average cheap eats...
# 3       kuta utara badung american asian low cheap eat...
# 4       ubud gianyar international indonesian average ...
#                               ...
# 2438    kuta badung seafood asian average fine dining ...
# 2439    kuta badung seafood indonesian low fine dining...
# 2440    kuta badung seafood asian low fine dining expe...
# 2441    kuta selatan badung seafood barbecue average f...
# 2442    kuta selatan badung seafood barbecue average f...
# Name: food_clean, Length: 2443, dtype: object

# %%
print(travel_df['combined_text'])
# Out:
# 0      tegallalang gianyar nature poi landmarks tegal...
# 1      kediri tabanan religious poi landmarks rock fo...
# 2      kuta badung religious temple regarded one sad ...
# 3      ubud gianyar scenic walking areas amid lush ra...
# 4      tampaksiring gianyar religious built 10thcentu...
#                              ...
# 656    karangasem karangasem park scenic former water...
# 657    baturiti tabanan nature village beatiful garde...
# 658    bangli bangli nature village traditional balin...
# 659    banjar buleleng hot springs geysers hot spring...
# 660    tegallalang gianyar nature farms sprawling ven...
# Name: combined_text, Length: 661, dtype: object

# %%
print(hotel_df['desc_clean'])
# Out:
# 0      blahbatuh gianyar expensive exceptional maxone...
# 1      gianyar gianyar expensive exceptional swan par...
# 2      kuta utara badung moderate good located dalung...
# 3      kubu karangasem expensive exceptional located ...
# 4      gianyar gianyar expensive wonderful offering o...
#                              ...
# 941    ubud gianyar moderate good featuring outdoor s...
# 942    ubud gianyar expensive exceptional peaceful re...
# 943    nusa penida klungkung moderate exceptional loc...
# 944    ubud gianyar expensive exceptional set ubud 24...
# 945    kuta badung expensive wonderful avani seminyak...
# Name: desc_clean, Length: 946, dtype: object

# %% [markdown]
# ###**Text Pre-Processing Travel**

# %%
import re
from nltk.corpus import stopwords as nltk_stopwords

clean_spcl = re.compile('[/(){}\[\]\|@,;]')
clean_symbol = re.compile('[^0-9a-z #+_]')
stop_words = set(nltk_stopwords.words('english'))

def clean_df(text):
    text = text.lower()
    text = re.sub("[^a-zA-Z0-9 ]", "", str(text))
    text = clean_spcl.sub(' ', text)
    text = clean_symbol.sub('', text)
    text = ' '.join(word for word in text.split() if word not in stop_words)
    return text


def clean_df(text):
    if isinstance(text, list):
        text = ' '.join(text)
    text = text.lower()
    text = re.sub("[^a-zA-Z0-9 ]", "", str(text))
    text = clean_spcl.sub(' ', text)
    text = clean_symbol.sub('', text)
    text = ' '.join(word for word in text.split() if word not in stop_words)
    return text

# %%
#selecting the relevant features for recommendation
selected_features_travel = ['rating_label', 'review_label','type_category','keywords','formatted_address','region']
print(selected_features_travel)
# Out:
# ['rating_label', 'review_label', 'type_category', 'keywords', 'formatted_address', 'region']

# %%
#Replace the null values with null string
for feature in selected_features_travel:
  travel_df[feature]= travel_df[feature].fillna('')
  travel_df[feature] = travel_df[feature].apply(clean_df)

# %%
# #menghitung jumlah missing data
# total_entry = np.product(travel_df.shape)
# total_missing = travel_df.isnull().sum().count()


# print("Persentase missing value awal terhadap data (dalam %): ", total_missing/total_entry * 100)
# print("")
# print("Jumlah missing value tiap column :")
# print(travel_df.isnull().sum())

# %%
travel_df.shape
# Out:
# (661, 12)

# %%
# Reset the index of the DataFrame
travel_df = travel_df.reset_index(drop=True)

# %%
print(travel_df['combined_text'] )
# Out:
# 0      tegallalang gianyar nature poi landmarks tegal...
# 1      kediri tabanan religious poi landmarks rock fo...
# 2      kuta badung religious temple regarded one sad ...
# 3      ubud gianyar scenic walking areas amid lush ra...
# 4      tampaksiring gianyar religious built 10thcentu...
#                              ...
# 656    karangasem karangasem park scenic former water...
# 657    baturiti tabanan nature village beatiful garde...
# 658    bangli bangli nature village traditional balin...
# 659    banjar buleleng hot springs geysers hot spring...
# 660    tegallalang gianyar nature farms sprawling ven...
# Name: combined_text, Length: 661, dtype: object

# %% [markdown]
# ###**Text Pre-Processing Food**

# %%
#selecting the relevant features for recommendation
selected_features_food = ['place_name', 'rating', 'cuisine','eating_type','price','region','comment','second_comment' ]
print(selected_features_travel)
# Out:
# ['rating_label', 'review_label', 'type_category', 'keywords', 'formatted_address', 'region']

# %%
#Replace the null values with null string
for feature in selected_features_food:
  food_df[feature]= food_df[feature].fillna('')
  food_df[feature] = food_df[feature].apply(clean_df)

# %%
food_df.shape
# Out:
# (2443, 15)

# %%
food_df.shape

# %% [markdown]
# ###**Text Pre-Processing Hotel**

# %%
#Drop Irrelevant Information
hotel_df = hotel_df.drop(["source_href"],axis=1)
hotel_df = hotel_df.drop_duplicates(subset='name_hotel')

# %%
# Reset the index of the DataFrame
hotel_df = hotel_df.reset_index(drop=True)

# %%
hotel_df.head()

# %%
hotel_df.shape

# %%
#selecting the relevant features for recommendation
selected_features_hotel = ['formatted_region', 'price_label','rating_type','description', 'formatted_address', 'region']
for feature in selected_features_hotel:
  hotel_df[feature]= hotel_df[feature].fillna('')
  hotel_df[feature] = hotel_df[feature].apply(clean_df)

# %%
hotel_df.head()

# %%
hotel_df['desc_clean'] = hotel_df['formatted_region'] + ' ' +  hotel_df['price_label'] + ' '+ hotel_df['rating_type'] + ' '  + hotel_df['description'] + ' ' + hotel_df['formatted_address'] + ' '+ hotel_df['region']

# %%
print(hotel_df['desc_clean'])

# %%
hotel_df.head()

# %% [markdown]
# ## **Model Hotel**

# %%
vectorizer = TfidfVectorizer(analyzer='word', ngram_range=(1,3), stop_words='english') #Diberikan parameter ini agar bisa melihat 1-2 kata secara bersamaan
tfidf_hotel = vectorizer.fit_transform(hotel_df['desc_clean'])

# %%
hotel_df.head()

# %%
def search_improv(query):
    query = clean_df(query)
    query_vector = vectorizer.transform([query])
    similarity_scores = cosine_similarity(query_vector, tfidf_hotel).flatten()
    top_indices = similarity_scores.argsort()[::-1][:10]  # Get the indices of the top 10 most similar places
    results = hotel_df.iloc[top_indices]
    return results

# %%
def search_improv_region(region, query):
    region = clean_df(region)
    query = clean_df(query)
    query_vector = vectorizer.transform([query])

    similarity_scores = cosine_similarity(query_vector, tfidf_hotel).flatten()

    # Split region into individual words
    region_words = region.split()

    # Filter based on region
    region_indices = hotel_df['region'].apply(lambda r: re.search(r'\b{}\b'.format(region), r, flags=re.IGNORECASE) is not None)
    filtered_scores = similarity_scores * region_indices

    top_indices = filtered_scores.argsort()[::-1][:10]
    results = hotel_df.iloc[top_indices]
    return results

# %%
import ipywidgets as widgets
from IPython.display import display

place_input = widgets.Text(
    value='',
    description='Enter your Location Information:',
    disabled=False
)
place_list = widgets.Output()

#Bakal dipanggil setiap ngetik di input field
def on_change(change):
    place_list.clear_output()
    query = place_input.value
    # preferences = preference_input.value
    if len(query) > 2:
        results = search_improv(query)
        with place_list:
            display(results)
    else:
        with place_list:
            display("Sorry, I couldn't find any matching destinations.")




# Step 8: Observe the changes in the input widgets and trigger the callback functions
place_input.observe(on_change, names='value')
# preference_input.observe(on_change, names='value')


#Display the input widgets and the search results
# display(place_input, place_list)
display(widgets.VBox([place_input]), place_list)

# %%
import ipywidgets as widgets
from IPython.display import display

region_input = widgets.Text(
    value='',
    description='Enter the Region:',
    disabled=False
)

place_input = widgets.Text(
    value='',
    description='Enter your Location Places:',
    disabled=False
)

place_list = widgets.Output()
# Check if the entered region is valid and return results accordingly
def check_region(region):
    valid_regions = set(hotel_df['region'])
    entered_region = clean_df(region.lower())

    for valid_region in valid_regions:
        if entered_region in valid_region:
            return True

    return False

#Bakal dipanggil setiap ngetik di input field
def on_change(change):
    place_list.clear_output()
    region = region_input.value
    query = place_input.value
    if len(region) > 2 and len(query) > 0:
        if check_region(region):
            results = search_improv_region(region, query)
            if not results.empty:
                with place_list:
                    display(results)
            else:
                with place_list:
                    display("Sorry, I couldn't find any matching destinations.")
        else:
            with place_list:
                display("Sorry, the entered region is not valid.")
    else:
        with place_list:
            display("Please enter both the region and the location/type of place.")

# Observe the changes in the input widgets and trigger the callback function
region_input.observe(on_change, names='value')
place_input.observe(on_change, names='value')

# Display the input widgets and the search results
display(widgets.VBox([region_input, place_input]), place_list)

# %% [markdown]
# ## **Model Travel Spot**

# %%
vectorizer = TfidfVectorizer(analyzer='word', ngram_range=(1,2), stop_words='english') #Diberikan parameter ini agar bisa melihat 1-2 kata secara bersamaan
tfidf = vectorizer.fit_transform(travel_df['combined_text'])

# %%
def search_improv(query):
    query = clean_df(query)
    query_vector = vectorizer.transform([query])

    similarity_scores = cosine_similarity(query_vector, tfidf).flatten()
    top_indices = similarity_scores.argsort()[::-1][:10]  # Get the indices of the top 10 most similar places
    results = travel_df.iloc[top_indices]
    return results

# %%
def search_improv_3(region, query):
    region = clean_df(region)
    query = clean_df(query)
    query_vector = vectorizer.transform([query])

    similarity_scores = cosine_similarity(query_vector, tfidf).flatten()

    # Filter based on region
    region_indices = travel_df['region'].str.contains(region, case=False, regex=False)
    filtered_scores = similarity_scores * region_indices

    top_indices = filtered_scores.argsort()[::-1][:5]
    results = travel_df.iloc[top_indices]
    return results

# %%
def calculate_recall(ground_truth, recommended_places, k):
    recall_sum = 0
    for user, true_places in ground_truth.items():
        recommended_k = recommended_places[user][:k]
        true_positive = len(set(recommended_k) & set(true_places))
        if len(true_places) > 0:
            recall = true_positive / len(true_places)
        else:
            recall = 0  # Set recall to 0 if there are no true places for the user
        recall_sum += recall
    recall_at_k = recall_sum / len(ground_truth)
    return recall_at_k


# def search_travel_spot(region, query):
#     region = clean_df(region)
#     query = clean_df(query)
    
#     # Split the query into individual parameters
#     parameters = query.split(',')
    
#     # Prepare the query string with all the parameters
#     query_string = f"{region} {' '.join(parameters)}"
    
#     query_vector = vectorizer.transform([query_string])

#     similarity_scores = cosine_similarity(query_vector, tfidf).flatten()

#     # Filter based on region
#     region_indices = travel_df['region'].str.contains(region, case=False, regex=False)
#     filtered_scores = similarity_scores * region_indices

#     top_indices = filtered_scores.argsort()[::-1]
#     results = travel_df.iloc[top_indices]
#     return results


def search_improv_3(region, query, ground_truth):
    region = clean_df(region)
    query = clean_df(query)
    query_categories = query.split(',')

    query_vector = vectorizer.transform([query])

    similarity_scores = cosine_similarity(query_vector, tfidf).flatten()

    # Filter based on region
    region_indices = travel_df['region'].str.contains(region, case=False, regex=False)
    filtered_scores = similarity_scores * region_indices

    top_indices = filtered_scores.argsort()[::-1][:5]
    results = travel_df.iloc[top_indices]

    # Filter results based on the same region and matching type_category
    filtered_results = []
    for index, row in results.iterrows():
        place_region = row['region']
        place_category = row['type_category']
        if place_region == region and any(category in place_category for category in query_categories):
            filtered_results.append(row['place'])

    recommended_places = {}
    for user, true_places in ground_truth.items():
        recommended_places[user] = filtered_results

    recall_at_3 = calculate_recall(ground_truth, recommended_places, 3)

    return filtered_results, recall_at_3


# Example usage
ground_truth = {
    "User1": ["tegalalang rice terrace", "tanah lot temple", "uluwatu temple"],
    "User2": ["campuhan ridge walk", "tirta empul temple", "jatiluwih green land"],
    "User3": ["tanah lot temple", "tirta empul temple", "uluwatu temple"],
}

results, recall = search_improv_3("kuta badung", "art, beach", ground_truth)

print("Recommended Places:", results)
print("Recall@3:", recall)

# %%
# Perform a search to check if 'Tirta Empul Temple' is in the dataset
search_result = travel_df[travel_df['place'] == 'uluwatu temple']

if not search_result.empty:
    print("is in the dataset.")
else:
    print("is not in the dataset.")

# %%
def search_improv_rating(region, query, rating=None):
    region = clean_df(region)
    query = clean_df(query)
    query_vector = vectorizer.transform([query])

    similarity_scores = cosine_similarity(query_vector, tfidf).flatten()

    # Filter based on region
    region_indices = travel_df['region '].str.contains(region, case=False, regex=False)
    filtered_scores = similarity_scores * region_indices

    if rating:
        if rating == 'low_rating':
            filtered_indices = travel_df[travel_df['rating_google'] < 3.5].index
        elif rating == 'average_rating':
            filtered_indices = travel_df[(travel_df['rating_google'] >= 3.5) & (travel_df['rating_google'] < 4.2)].index
        elif rating == 'high_rating':
            filtered_indices = travel_df[travel_df['rating_google'] >= 4.2].index
        else:
            filtered_indices = travel_df.index
    else:
        filtered_indices = travel_df.index

    filtered_scores[~travel_df.index.isin(filtered_indices)] = 0  # Set filtered scores of non-matching ratings to 0

    top_indices = filtered_scores.argsort()[::-1][:10]  # Get the indices of the top 10 most similar places
    results = travel_df.iloc[top_indices]
    return results

# %%
# Check if the entered region is valid and return results accordingly
def check_region_travel(region):
    valid_regions = set(travel_df['region '])
    entered_region = clean_df(region.lower())

    for valid_region in valid_regions:
        if entered_region in valid_region:
            return True

    return False

# %%
import ipywidgets as widgets
from IPython.display import display

place_input = widgets.Text(
    value='',
    description='Enter your Location Places:',
    disabled=False
)
place_list = widgets.Output()

#Bakal dipanggil setiap ngetik di input field
def on_change(change):
    place_list.clear_output()
    query = place_input.value
    # preferences = preference_input.value
    if len(query) > 2:
        results = search_improv(query)
        with place_list:
            display(results)
    else:
        with place_list:
            display("Sorry, I couldn't find any matching destinations.")




# Step 8: Observe the changes in the input widgets and trigger the callback functions
place_input.observe(on_change, names='value')
# preference_input.observe(on_change, names='value')


#Display the input widgets and the search results
# display(place_input, place_list)
display(widgets.VBox([place_input]), place_list)

# %%
import ipywidgets as widgets
from IPython.display import display

region_input = widgets.Text(
    value='',
    description='Enter the Region:',
    disabled=False
)

place_input = widgets.Text(
    value='',
    description='Enter your Location Places:',
    disabled=False
)

place_list = widgets.Output()


#Bakal dipanggil setiap ngetik di input field
def on_change(change):
    place_list.clear_output()
    region = region_input.value
    query = place_input.value
    if len(region) > 2 and len(query) > 0:
        if check_region(region):
            results = search_improv_3(region, query)
            if not results.empty:
                with place_list:
                    display(results)
            else:
                with place_list:
                    display("Sorry, I couldn't find any matching destinations.")
        else:
            with place_list:
                display("Sorry, the entered region is not valid.")
    else:
        with place_list:
            display("Please enter both the region and the location/type of place.")

# Observe the changes in the input widgets and trigger the callback function
region_input.observe(on_change, names='value')
place_input.observe(on_change, names='value')

# Display the input widgets and the search results
display(widgets.VBox([region_input, place_input]), place_list)

# %%
import ipywidgets as widgets
from IPython.display import display

# Define the input widgets
region_input = widgets.Text(
    value='',
    description='Enter the Region:',
    disabled=False
)

place_input = widgets.Text(
    value='',
    description='Enter your Location Places:',
    disabled=False
)

rating_input = widgets.Dropdown(
    options=['', 'low_rating', 'average_rating', 'high_rating'],
    value='',
    description='Rating:',
    disabled=False
)

place_list = widgets.Output()

# Define the callback function for changes in input widgets
def on_change(change):
    place_list.clear_output()
    region = region_input.value
    query = place_input.value
    rating = rating_input.value

    if len(region) > 2 and len(query) > 0:
        if check_region_travel(region):
            results = search_improv_rating(region, query, rating)
            if not results.empty:
                with place_list:
                    display(results)
            else:
                with place_list:
                    display("Sorry, I couldn't find any matching destinations.")
        else:
            with place_list:
                display("Sorry, the entered region is not valid.")
    else:
        with place_list:
            display("Please enter both the region and the location/type of place.")

# Observe the changes in the input widgets and trigger the callback functions
region_input.observe(on_change, names='value')
place_input.observe(on_change, names='value')
rating_input.observe(on_change, names='value')

# Display the input widgets and the search results
display(widgets.VBox([region_input, place_input, rating_input]), place_list)

# %% [markdown]
# ## **Final Model**

# %%
import ipywidgets as widgets
from IPython.display import display
import random
import re
from nltk.corpus import stopwords as nltk_stopwords


vectorizer = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), stop_words='english')
tfidf = vectorizer.fit_transform(travel_df['combined_text'])
tfidf_hotel = vectorizer.transform(hotel_df['desc_clean'])
tfidf_food = vectorizer.transform(food_df['food_clean'])

def check_region_travel(region):
    valid_regions = set(travel_df['region'])
    entered_region = clean_df(region.lower())

    for valid_region in valid_regions:
        if entered_region in valid_region:
            return True

    return False



clean_spcl = re.compile('[/(){}\[\]\|@,;]')
clean_symbol = re.compile('[^0-9a-z #+_]')
stop_words = set(nltk_stopwords.words('english'))

def clean_df(text):
    if isinstance(text, list):
        text = ' '.join(text)
    text = text.lower()
    text = re.sub("[^a-zA-Z0-9 ]", "", str(text))
    text = clean_spcl.sub(' ', text)
    text = clean_symbol.sub('', text)
    text = ' '.join(word for word in text.split() if word not in stop_words)
    return text

region_input_travel = widgets.Text(
    value='',
    description='Enter the Regions for Travel (comma-separated):',
    disabled=False
)

place_input_travel = widgets.Text(
    value='',
    description='Enter your Location/Type of Place for Travel:',
    disabled=False
)

place_input_hotel = widgets.Text(
    value='',
    description='Enter your Description/Keywords for Hotel:',
    disabled=False
)

food_input = widgets.Text(
    value='',
    description='Enter your Food Preferences:',
    disabled=False
)

duration_input = widgets.Text(
    value='',
    description='Enter the Duration of Travel (in days):',
    disabled=False
)

travel_place_list = widgets.Output()
hotel_place_list = widgets.Output()
food_list = widgets.Output()

def get_top_recommendations(df, num_recommendations):
    return df.head(num_recommendations)

def generate_itinerary(regions, travel_preferences, hotel_preferences, food_preferences, duration):
    itinerary = "Great! Here's your itinerary for your trip:\n\n"
    
    num_days_per_region = duration // len(regions)
    remaining_days = duration % len(regions)
    
    for i, region in enumerate(regions):
        if i == len(regions) - 1:
            if remaining_days > 0:
                itinerary += f"Day {i*num_days_per_region+1}-{i*num_days_per_region+num_days_per_region+remaining_days}: {region}\n"
                remaining_days -= 1
            else:
                itinerary += f"Day {i*num_days_per_region+1}-{i*num_days_per_region+num_days_per_region}: {region}\n"
        else:
            itinerary += f"Day {i*num_days_per_region+1}-{i*num_days_per_region+num_days_per_region}: {region}\n"
        
        # Travel Spot Recommendations
        travel_results = pd.DataFrame()
        travel_results = search_travel_spot(region, travel_preferences)
        num_travel_recommendations = min(10, len(travel_results))
        top_travel_recommendations = get_top_recommendations(travel_results, num_travel_recommendations)
    
        # Select travel recommendations based on travel preferences
        if len(travel_preferences) > 0:
            preferred_travel_results = top_travel_recommendations[
                top_travel_recommendations['type_category'].str.contains('|'.join(travel_preferences), case=False)
            ]
            num_preferred_travel_recommendations = min(5, len(preferred_travel_results))
            travel_recommendations = get_top_recommendations(preferred_travel_results, num_preferred_travel_recommendations)
        else:
            travel_recommendations = top_travel_recommendations.head(5)
        
        if not travel_recommendations.empty:
            itinerary += f"Stay at the "
            
            # Hotel Recommendation
            hotel_results = pd.DataFrame()
            hotel_results = search_hotels(region, hotel_preferences)
            num_hotel_recommendations = min(10, len(hotel_results))
            top_hotel_recommendations = get_top_recommendations(hotel_results, num_hotel_recommendations)
            
            # Select hotel recommendation
            hotel_recommendation = top_hotel_recommendations.head(1)
            
            if not hotel_recommendation.empty:
                itinerary += f"{hotel_recommendation['name_hotel'].iloc[0]} or any other hotel of your choice from the list.\n"
                
                if not travel_recommendations.empty:
                    itinerary += "Explore "
                    for _, spot in travel_recommendations.iterrows():
                        itinerary += spot['place'] + ", "
                    itinerary = itinerary[:-2] + ".\n\n"
                else:
                    itinerary += "\n"
                
                # Food Place Recommendations
                food_results = pd.DataFrame()
                food_results = search_food(region, food_preferences)
                num_food_recommendations = min(10, len(food_results))
                top_food_recommendations = get_top_recommendations(food_results, num_food_recommendations)
                
                # Filter food recommendations based on cuisine
                if len(food_preferences) > 0:
                    preferred_food_results = food_results[
                        food_results['cuisine'].str.contains('|'.join(food_preferences), case=False)
                    ]
                    num_food_recommendations = min(5, len(preferred_food_results))
                    top_food_recommendations = get_top_recommendations(preferred_food_results, num_food_recommendations)
                else:
                    top_food_recommendations = food_results.head(5)
                
                if not top_food_recommendations.empty:
                    itinerary += "Recommendations for places to eat near you:\n"
                    for _, food in top_food_recommendations.iterrows():
                        itinerary += "- " + food['place_name'] + "\n"
                    itinerary += "\n"
                else:
                    itinerary += "No food recommendations found.\n\n"
            else:
                itinerary += "No hotel recommendations found.\n\n"
        else:
            itinerary += "No travel recommendations found.\n\n"
    
    itinerary += f"For your transportation needs, you can rent a minivan for ${random.randint(30, 100)}/day or a passenger van for ${random.randint(30, 100)}/day.\n"
    return itinerary

def search_travel_spot(region, query):
    region = clean_df(region)
    query = clean_df(query)
    
    # Split the query into individual parameters
    parameters = query.split(',')
    
    # Prepare the query string with all the parameters
    query_string = f"{region} {' '.join(parameters)}"   
    query_vector = vectorizer.transform([query_string])
    similarity_scores = cosine_similarity(query_vector, tfidf).flatten()

    # Filter based on region
    region_indices = travel_df['region'].str.contains(region, case=False, regex=False)
    filtered_scores = similarity_scores * region_indices

    top_indices = filtered_scores.argsort()[::-1]
    results = travel_df.iloc[top_indices]
    return results


def search_hotels(region, query):
    region = clean_df(region)
    query = clean_df(query)
    
    # Split the query into individual parameters
    parameters = query.split(',')
    
    # Prepare the query string with all the parameters
    query_string = f"{region} {' '.join(parameters)}"
    query_vector = vectorizer.transform([query_string])
    similarity_scores = cosine_similarity(query_vector, tfidf_hotel).flatten()

    # Filter based on region
    region_indices = hotel_df['formatted_region'].str.contains(region, case=False, regex=False)
    filtered_scores = similarity_scores * region_indices

    top_indices = filtered_scores.argsort()[::-1]
    results = hotel_df.iloc[top_indices]
    return results

def search_food(region, query):
    region = clean_df(region)
    query = clean_df(query)

    # Split the query into individual parameters
    parameters = [param.strip() for param in query.split(',')]

    results = pd.DataFrame()

    for preference in parameters:
        # Prepare the query string with the current preference
        query_string = f"{region} {preference.strip()}"
        query_vector = vectorizer.transform([query_string])
        similarity_scores = cosine_similarity(query_vector, tfidf_food).flatten()

        # Filter based on region
        region_indices = food_df['formatted_region'].str.contains(region, case=False, regex=False)
        filtered_scores = similarity_scores * region_indices

        top_indices = filtered_scores.argsort()[::-1]
        preference_results = food_df.iloc[top_indices]
        
        results = pd.concat([results, preference_results], ignore_index=True)

    return results



def on_submit(change):
    travel_place_list.clear_output()
    hotel_place_list.clear_output()
    food_list.clear_output()
    
    regions = region_input_travel.value.split(',')
    travel_preferences = place_input_travel.value.split(',')
    hotel_preferences = place_input_hotel.value.split(',')
    food_preferences = food_input.value.split(',')
    duration = duration_input.value
    
    if len(regions) > 0 and len(travel_preferences) > 0 and len(hotel_preferences) > 0 and len(food_preferences) > 0 and duration.isdigit() and int(duration) > 0:
        valid_regions = []
        for region in regions:
            if check_region_travel(region):
                valid_regions.append(region.strip())
        
        if valid_regions:
            itinerary = generate_itinerary(valid_regions, travel_preferences, hotel_preferences, food_preferences, int(duration))
            with travel_place_list:
                display(itinerary)
        else:
            with travel_place_list:
                display("Sorry, the entered regions are not valid.")
    else:
        with travel_place_list:
            display("Please enter valid regions, location/type of place for travel, description/keywords for hotel, food preferences, and duration of travel (in days).")

# Observe the changes in the input widgets and trigger the callback functions
region_input_travel.on_submit(on_submit)
place_input_travel.on_submit(on_submit)
place_input_hotel.on_submit(on_submit)
food_input.on_submit(on_submit)
duration_input.on_submit(on_submit)

# Display the input widgets
display(widgets.VBox([region_input_travel, place_input_travel, place_input_hotel, food_input, duration_input]))

# Initialize the output placeholders
display(travel_place_list)
display(hotel_place_list)
display(food_list)
# Out:
# ...
# Output()
# Output()
# Output()
